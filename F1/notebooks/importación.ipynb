# %% [markdown]
# ## Importación de librerías
#
# Se importarán las principales librerías necesarias para la importación, manipulación, análisis y visualización de los datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMPORTACIÓN DE DATOS

# %%
# Definimos la ruta relativa del archivo original.
ruta_data = "../../data/raw/listings.csv.gz"

# Utilizamos Pandas para leer el archivo CSV comprimido.
df = pd.read_csv(ruta_data)

# Mostramos las primeras 5 filas para comprobar
# que los datos fueron importados correctamente.
df.head()
df.head()
# Out:
#                     id                                       listing_url  \
# 0   978070332077815549   https://www.airbnb.com/rooms/978070332077815549
# 1  1069858035768058539  https://www.airbnb.com/rooms/1069858035768058539
# 2             37181369             https://www.airbnb.com/rooms/37181369
# 3  1257358306712011993  https://www.airbnb.com/rooms/1257358306712011993
# 4   868747298775934782   https://www.airbnb.com/rooms/868747298775934782
#
#         scrape_id last_scraped       source  \
# 0  20260629151853   2026-07-01  city scrape
# 1  20260629151853   2026-06-30  city scrape
# 2  20260629151853   2026-06-30  city scrape
# 3  20260629151853   2026-07-01  city scrape
# 4  20260629151853   2026-07-01  city scrape
#
#                                               name  \
# 0                     luminosa mansarda con balcón
# 1  Cómoda habitación bien ubicada con baño privado
# 2               Cómodo departamento Cerca de Metro
# ...
